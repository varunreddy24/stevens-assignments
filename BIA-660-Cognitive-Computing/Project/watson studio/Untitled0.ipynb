# %%
# !pip install -U -q imblearn
import os, types
import pandas as pd
# from botocore.client import Config
# import ibm_boto3
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_b0526e14e5c849c0b938bf280dcd4db8 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='4sejyU41g9YKDYMV6UJ696q-UEAtdL6X4VI3A8KwZnJS',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

body = client_b0526e14e5c849c0b938bf280dcd4db8.get_object(Bucket='heartdiseasedetection-donotdelete-pr-x9rghlscz98ju4',Key='heart_2020_cleaned.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# %% [markdown]
# ### Authenticating Google Drive and importing neccessary dataset

# %%
data = pd.read_csv(body)
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
data.info()
print("Dimensions of the data:", data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB
# Dimensions of the data: (319795, 18)

# %%
data.describe(include='all').T
# Out:
#                      count unique        top    freq       mean       std  \
# HeartDisease        319795      2         No  292422        NaN       NaN
# BMI               319795.0    NaN        NaN     NaN  28.325399    6.3561
# Smoking             319795      2         No  187887        NaN       NaN
# AlcoholDrinking     319795      2         No  298018        NaN       NaN
# Stroke              319795      2         No  307726        NaN       NaN
# PhysicalHealth    319795.0    NaN        NaN     NaN    3.37171   7.95085
# MentalHealth      319795.0    NaN        NaN     NaN   3.898366  7.955235
# DiffWalking         319795      2         No  275385        NaN       NaN
# Sex                 319795      2     Female  167805        NaN       NaN
# AgeCategory         319795     13      65-69   34151        NaN       NaN
# Race                319795      6      White  245212        NaN       NaN
# Diabetic            319795      4         No  269653        NaN       NaN
# PhysicalActivity    319795      2        Yes  247957        NaN       NaN
# GenHealth           319795      5  Very good  113858        NaN       NaN
# SleepTime         319795.0    NaN        NaN     NaN   7.097075  1.436007
# Asthma              319795      2         No  276923        NaN       NaN
# KidneyDisease       319795      2         No  308016        NaN       NaN
# SkinCancer          319795      2         No  289976        NaN       NaN
#
#                     min    25%    50%    75%    max
# HeartDisease        NaN    NaN    NaN    NaN    NaN
# BMI               12.02  24.03  27.34  31.42  94.85
# Smoking             NaN    NaN    NaN    NaN    NaN
# AlcoholDrinking     NaN    NaN    NaN    NaN    NaN
# Stroke              NaN    NaN    NaN    NaN    NaN
# PhysicalHealth      0.0    0.0    0.0    2.0   30.0
# MentalHealth        0.0    0.0    0.0    3.0   30.0
# DiffWalking         NaN    NaN    NaN    NaN    NaN
# Sex                 NaN    NaN    NaN    NaN    NaN
# AgeCategory         NaN    NaN    NaN    NaN    NaN
# Race                NaN    NaN    NaN    NaN    NaN
# Diabetic            NaN    NaN    NaN    NaN    NaN
# PhysicalActivity    NaN    NaN    NaN    NaN    NaN
# GenHealth           NaN    NaN    NaN    NaN    NaN
# SleepTime           1.0    6.0    7.0    8.0   24.0
# Asthma              NaN    NaN    NaN    NaN    NaN
# KidneyDisease       NaN    NaN    NaN    NaN    NaN
# SkinCancer          NaN    NaN    NaN    NaN    NaN

# %% [markdown]
# ## 1. Extracting Numeric Data and doing EDA on the data

# %%
numeric_data = data._get_numeric_data()
scaler = StandardScaler()
scaler.fit(numeric_data)
numeric_data[numeric_data.columns] = scaler.transform(numeric_data)

# %%
scaler.var_
# Out:
# array([40.39988343, 63.21582095, 63.28556949,  2.06210983])

# %%
plt.figure(figsize=(10,8))
sns.set_theme(style="whitegrid")
sns.boxplot(data=numeric_data, showfliers=False)  # outliers are ignore to be plotted
plt.xlabel("Numerical Attributes", fontsize= 12)
plt.ylabel("Values", fontsize= 12)
plt.title("Numerical Attributes Boxplot", fontsize= 15)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.set_theme(style="whitegrid")
sns.violinplot(data=numeric_data)
plt.xlabel("Numerical Attributes", fontsize= 12)
plt.ylabel("Values", fontsize= 12)
plt.title("Numerical Attributes Violin plots", fontsize= 15)
plt.show()

# %%
numeric_data = numeric_data.join(data['HeartDisease'])

# %%
sns.heatmap(numeric_data.iloc[:, 0:].corr(), annot=True)
plt.show()

# %% [markdown]
# ## 2. Extracting categorical data and doing EDA

# %%
categorical_data = data.select_dtypes(include=['object'])
categorical_data
# Out:
#        HeartDisease Smoking AlcoholDrinking Stroke DiffWalking     Sex  \
# 0                No     Yes              No     No          No  Female
# 1                No      No              No    Yes          No  Female
# 2                No     Yes              No     No          No    Male
# 3                No      No              No     No          No  Female
# 4                No      No              No     No         Yes  Female
# ...             ...     ...             ...    ...         ...     ...
# 319790          Yes     Yes              No     No         Yes    Male
# 319791           No     Yes              No     No          No    Male
# 319792           No      No              No     No          No  Female
# 319793           No      No              No     No          No  Female
# 319794           No      No              No     No          No  Female
#
#         AgeCategory      Race Diabetic PhysicalActivity  GenHealth Asthma  \
# 0             55-59     White      Yes              Yes  Very good    Yes
# 1       80 or older     White       No              Yes  Very good     No
# 2             65-69     White      Yes              Yes       Fair    Yes
# 3             75-79     White       No               No       Good     No
# 4             40-44     White       No              Yes  Very good     No
# ...             ...       ...      ...              ...        ...    ...
# 319790        60-64  Hispanic      Yes               No       Fair    Yes
# 319791        35-39  Hispanic       No              Yes  Very good    Yes
# 319792        45-49  Hispanic       No              Yes       Good     No
# 319793        25-29  Hispanic       No               No       Good     No
# 319794  80 or older  Hispanic       No              Yes       Good     No
#
#        KidneyDisease SkinCancer
# 0                 No        Yes
# 1                 No         No
# 2                 No         No
# 3                 No        Yes
# 4                 No         No
# ...              ...        ...
# 319790            No         No
# 319791            No         No
# 319792            No         No
# 319793            No         No
# 319794            No         No
#
# [319795 rows x 14 columns]

# %%
categorical_data.describe()
# Out:
#        HeartDisease Smoking AlcoholDrinking  Stroke DiffWalking     Sex  \
# count        319795  319795          319795  319795      319795  319795
# unique            2       2               2       2           2       2
# top              No      No              No      No          No  Female
# freq         292422  187887          298018  307726      275385  167805
#
#        AgeCategory    Race Diabetic PhysicalActivity  GenHealth  Asthma  \
# count       319795  319795   319795           319795     319795  319795
# unique          13       6        4                2          5       2
# top          65-69   White       No              Yes  Very good      No
# freq         34151  245212   269653           247957     113858  276923
#
#        KidneyDisease SkinCancer
# count         319795     319795
# unique             2          2
# top               No         No
# freq          308016     289976

# %%
position_index = [(0,0),(0,1),(0,2),(1,0),(1,1),(1,2),(2,0),(2,1),(2,2),(3,0),(3,1),(3,2),(4,0),(4,1),(4,2)]
fig,axes = plt.subplots(5,3,figsize=(20,45))

for position, feature in zip(position_index, categorical_data.columns.tolist()[:]):
    if len(categorical_data[feature].unique()) > 15:
        sns.histplot(ax=axes[position],bins = 15, data=categorical_data[feature].sort_values())
    else:
        if feature in ["AgeCategory", "Race"]:
            i, r = pd.factorize(categorical_data[feature])
            a = np.argsort(np.bincount(i)[i], kind='mergesort')[::-1]
            sns.histplot(ax=axes[position],y=categorical_data.iloc[a][feature])
        elif feature == "GenHealth":
            sns.histplot(ax=axes[position],data=pd.Categorical(categorical_data.GenHealth, categories=["Poor","Fair","Good","Very good","Excellent"], ordered=True))
            axes[position].set(xlabel=feature)
        else:
            sns.histplot(ax=axes[position],data=categorical_data[feature].sort_values())
    axes[position].set_title(f'{feature} histogram')

# %%
all_maps = {
  'HeartDisease_map' : {'No':0, 'Yes': 1},
  'Smoking_map' : {'No':0, 'Yes': 1},
  'AlcoholDrinking_map' : {'No':0, 'Yes': 1},
  'Stroke_map' : {'No':0, 'Yes': 1},
  'DiffWalking_map' : {'No':0, 'Yes': 1},
  'Sex_map' : {'Female': 0, 'Male': 1},
  'Asthma_map' : {'No':0, 'Yes': 1},
  'KidneyDisease_map' : {'No':0, 'Yes': 1},
  'SkinCancer_map' : {'No':0, 'Yes': 1},
  'PhysicalActivity_map' : {'No':0, 'Yes': 1},
  
  'AgeCategory_map' : {'18-24':0 , '25-29': 1, '30-34': 2, '35-39': 3, '40-44': 4, 
                    '45-49': 5, '50-54': 6,'55-59': 7, '60-64': 8, '65-69': 9, 
                    '70-74': 10, '75-79': 11, '80 or older': 12},
  'Race_map' : {'White': 0, 'Black': 1, 'Asian': 2, 
              'American Indian/Alaskan Native': 3, 'Hispanic': 4, 'Other': 5},
  'Diabetic_map' : {'No':0, 'No, borderline diabetes': 1, 'Yes (during pregnancy)': 2,
                    'Yes': 3},
  'GenHealth_map' : {'Poor': 0, 'Fair': 1, 'Good': 2, 'Very good': 3, 'Excellent': 4}
  
}

# %%
def encode_data(data: pd.core.frame.DataFrame) -> pd.core.frame.DataFrame:
    data_copy = data.copy()
    columns = data.columns.to_list()
    for column in columns:
        data_copy[column] = data[column].replace(all_maps[column+'_map'])
    return data_copy

# %%
df_encoded = encode_data(categorical_data.iloc[:, 1:])

# %%
df_encoded = df_encoded.join(categorical_data['HeartDisease'])

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_encoded.corr(), annot=True)
plt.show()

# %%
def plot_kde(feature):
    figure, axis = plt.subplots(1, 1, figsize=(15, 5))
    sns.histplot(data=categorical_data, x=feature, hue="HeartDisease", multiple="dodge", shrink=.8, hue_order = ['Yes', 'No'])
    plt.title(f'{feature} with Heart Disease')
    
    plt.show()

# %%
for feature in categorical_data.iloc[:, 1:]:
    plot_kde(feature)

# %% [markdown]
# ## 3. Trying to balance the imbalanced data

# %%
data_copy = numeric_data.iloc[:, :-1].join(df_encoded)
data_copy.head()
# Out:
#         BMI  PhysicalHealth  MentalHealth  SleepTime  Smoking  \
# 0 -1.844750       -0.046751      3.281069  -1.460354        1
# 1 -1.256338       -0.424070     -0.490039  -0.067601        0
# 2 -0.274603        2.091388      3.281069   0.628776        1
# 3 -0.647473       -0.424070     -0.490039  -0.763977        0
# 4 -0.726138        3.097572     -0.490039   0.628776        0
#
#    AlcoholDrinking  Stroke  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0                0       0            0    0            7     0         3
# 1                0       1            0    0           12     0         0
# 2                0       0            0    1            9     0         3
# 3                0       0            0    0           11     0         0
# 4                0       0            1    0            4     0         0
#
#    PhysicalActivity  GenHealth  Asthma  KidneyDisease  SkinCancer HeartDisease
# 0                 1          3       1              0           1           No
# 1                 1          3       0              0           0           No
# 2                 1          1       1              0           0           No
# 3                 0          2       0              0           1           No
# 4                 1          3       0              0           0           No

# %%
smote = SMOTE()
X,y = smote.fit_resample(data_copy.iloc[:, :-1], data_copy.iloc[:, -1])
data_oversampled = X.join(y)
data_oversampled.head()
# Out:
#         BMI  PhysicalHealth  MentalHealth  SleepTime  Smoking  \
# 0 -1.844750       -0.046751      3.281069  -1.460354        1
# 1 -1.256338       -0.424070     -0.490039  -0.067601        0
# 2 -0.274603        2.091388      3.281069   0.628776        1
# 3 -0.647473       -0.424070     -0.490039  -0.763977        0
# 4 -0.726138        3.097572     -0.490039   0.628776        0
#
#    AlcoholDrinking  Stroke  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0                0       0            0    0            7     0         3
# 1                0       1            0    0           12     0         0
# 2                0       0            0    1            9     0         3
# 3                0       0            0    0           11     0         0
# 4                0       0            1    0            4     0         0
#
#    PhysicalActivity  GenHealth  Asthma  KidneyDisease  SkinCancer HeartDisease
# 0                 1          3       1              0           1           No
# 1                 1          3       0              0           0           No
# 2                 1          1       1              0           0           No
# 3                 0          2       0              0           1           No
# 4                 1          3       0              0           0           No

# %%
data_oversampled.columns
# Out:
# Index(['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime', 'Smoking',
#        'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma',
#        'KidneyDisease', 'SkinCancer', 'HeartDisease'],
#       dtype='object')

# %%
before_sampling = list(Counter(data_copy['HeartDisease']).items())
after_sampling = list(Counter(data_oversampled['HeartDisease']).items())

# %%
print("Before Oversampling \t %s: %d, %s: %d" %(before_sampling[0][0], before_sampling[0][1], before_sampling[1][0], before_sampling[1][1]))
print("After Oversampling \t %s: %d, %s: %d" %(after_sampling[0][0], after_sampling[0][1], after_sampling[1][0], after_sampling[1][1]))
# Out:
# Before Oversampling 	 No: 292422, Yes: 27373
# After Oversampling 	 No: 292422, Yes: 292422

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(data_copy.iloc[:, :-1], data_copy.iloc[:, -1])
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(data_oversampled.iloc[:, :-1], data_oversampled.iloc[:, -1])

# %%
from sklearn.neural_network import MLPClassifier

clf1 = MLPClassifier()
clf2 = MLPClassifier()

clf1.fit(X_train_1, y_train_1)
clf2.fit(X_train_2, y_train_2)

pred1 = clf1.predict(X_test_1)
pred2 = clf2.predict(X_test_2)

print("Accuracy 1:", accuracy_score(y_test_1, pred1))
print("Accuracy 2:", accuracy_score(y_test_2, pred2))

print("Confusion 1:", confusion_matrix(y_test_1, pred1))
print("Confusion 2:", confusion_matrix(y_test_2, pred2))
# Out:
# Accuracy 1: 0.9143078712679333
# Accuracy 2: 0.7832174049832092
# Confusion 1: [[72347   648]
#  [ 6203   751]]
# Confusion 2: [[55294 17677]
#  [14019 59221]]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Normalization, Layer, Concatenate
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Precision, Recall

# %%
data_oversampled.iloc[0]
# Out:
# BMI                 -1.84475
# PhysicalHealth     -0.046751
# MentalHealth        3.281069
# SleepTime          -1.460354
# Smoking                    1
# AlcoholDrinking            0
# Stroke                     0
# DiffWalking                0
# Sex                        0
# AgeCategory                7
# Race                       0
# Diabetic                   3
# PhysicalActivity           1
# GenHealth                  3
# Asthma                     1
# KidneyDisease              0
# SkinCancer                 1
# HeartDisease              No
# Name: 0, dtype: object

# %%
def PreProcessing(Layer):
    def __init__(self, mean, var, maps, **kwargs):
        super(PreProcessing, self).__init__(**kwargs)
        
        self.scaler_layer = Normalization(mean=mean, variance=var)
        self.maps = maps
    
    def mapping_input(self, data):
        
    def call(self, input_layer: Layer):
        scaler_input = input_layer[:4]
        categorical_input = input_layer[4:]
        scaled_input = self.scaler_layer(scaler_input)
        
        categorized_input = input_layer[4:]

# %%
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(X_train_2.shape[1], )))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['Accuracy', Precision(), Recall()])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               4608
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_2, y_train_2.replace(all_maps['HeartDisease_map']), epochs=100, verbose=1, batch_size=64, validation_data=(X_test_2, y_test_2.replace(all_maps['HeartDisease_map'])))
# Out:
# Epoch 1/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.4897 - Accuracy: 0.7667 - precision_1: 0.7456 - recall_1: 0.8093 - val_loss: 0.4828 - val_Accuracy: 0.7699 - val_precision_1: 0.7448 - val_recall_1: 0.8216
# Epoch 2/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4805 - Accuracy: 0.7731 - precision_1: 0.7538 - recall_1: 0.8108 - val_loss: 0.4801 - val_Accuracy: 0.7739 - val_precision_1: 0.7630 - val_recall_1: 0.7950
# Epoch 3/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4755 - Accuracy: 0.7754 - precision_1: 0.7555 - recall_1: 0.8141 - val_loss: 0.4761 - val_Accuracy: 0.7732 - val_precision_1: 0.7356 - val_recall_1: 0.8533
# Epoch 4/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4707 - Accuracy: 0.7780 - precision_1: 0.7573 - recall_1: 0.8181 - val_loss: 0.4713 - val_Accuracy: 0.7783 - val_precision_1: 0.7604 - val_recall_1: 0.8129
# Epoch 5/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4658 - Accuracy: 0.7805 - precision_1: 0.7594 - recall_1: 0.8209 - val_loss: 0.4659 - val_Accuracy: 0.7796 - val_precision_1: 0.7722 - val_recall_1: 0.7936
# Epoch 6/100
# 6854/6854 [==============================] - 41s 6ms/step - loss: 0.4603 - Accuracy: 0.7836 - precision_1: 0.7624 - recall_1: 0.8241 - val_loss: 0.4636 - val_Accuracy: 0.7819 - val_precision_1: 0.7602 - val_recall_1: 0.8241
# Epoch 7/100
# 6854/6854 [==============================] - 40s 6ms/step - loss: 0.4551 - Accuracy: 0.7870 - precision_1: 0.7639 - recall_1: 0.8306 - val_loss: 0.4649 - val_Accuracy: 0.7783 - val_precision_1: 0.7824 - val_recall_1: 0.7714
# Epoch 8/100
# 6854/6854 [==============================] - 39s 6ms/step - loss: 0.4500 - Accuracy: 0.7896 - precision_1: 0.7660 - recall_1: 0.8340 - val_loss: 0.4597 - val_Accuracy: 0.7829 - val_precision_1: 0.7719 - val_recall_1: 0.8035
# Epoch 9/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4452 - Accuracy: 0.7926 - precision_1: 0.7679 - recall_1: 0.8384 - val_loss: 0.4554 - val_Accuracy: 0.7860 - val_precision_1: 0.7472 - val_recall_1: 0.8649
# Epoch 10/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4401 - Accuracy: 0.7953 - precision_1: 0.7702 - recall_1: 0.8415 - val_loss: 0.4541 - val_Accuracy: 0.7872 - val_precision_1: 0.7713 - val_recall_1: 0.8168
# Epoch 11/100
# 6854/6854 [==============================] - 41s 6ms/step - loss: 0.4356 - Accuracy: 0.7978 - precision_1: 0.7721 - recall_1: 0.8450 - val_loss: 0.4517 - val_Accuracy: 0.7888 - val_precision_1: 0.7815 - val_recall_1: 0.8021
# Epoch 12/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.4318 - Accuracy: 0.7999 - precision_1: 0.7740 - recall_1: 0.8470 - val_loss: 0.4492 - val_Accuracy: 0.7909 - val_precision_1: 0.7646 - val_recall_1: 0.8409
# Epoch 13/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4273 - Accuracy: 0.8026 - precision_1: 0.7766 - recall_1: 0.8495 - val_loss: 0.4471 - val_Accuracy: 0.7922 - val_precision_1: 0.7616 - val_recall_1: 0.8510
# Epoch 14/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4236 - Accuracy: 0.8044 - precision_1: 0.7784 - recall_1: 0.8510 - val_loss: 0.4452 - val_Accuracy: 0.7942 - val_precision_1: 0.7616 - val_recall_1: 0.8570
# Epoch 15/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.4197 - Accuracy: 0.8064 - precision_1: 0.7798 - recall_1: 0.8538 - val_loss: 0.4442 - val_Accuracy: 0.7955 - val_precision_1: 0.7676 - val_recall_1: 0.8481
# Epoch 16/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4160 - Accuracy: 0.8088 - precision_1: 0.7822 - recall_1: 0.8560 - val_loss: 0.4429 - val_Accuracy: 0.7958 - val_precision_1: 0.7726 - val_recall_1: 0.8388
# Epoch 17/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.4127 - Accuracy: 0.8105 - precision_1: 0.7833 - recall_1: 0.8585 - val_loss: 0.4412 - val_Accuracy: 0.7981 - val_precision_1: 0.7641 - val_recall_1: 0.8626
# Epoch 18/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4096 - Accuracy: 0.8125 - precision_1: 0.7849 - recall_1: 0.8609 - val_loss: 0.4437 - val_Accuracy: 0.7970 - val_precision_1: 0.7632 - val_recall_1: 0.8615
# Epoch 19/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4063 - Accuracy: 0.8145 - precision_1: 0.7868 - recall_1: 0.8627 - val_loss: 0.4415 - val_Accuracy: 0.7975 - val_precision_1: 0.7649 - val_recall_1: 0.8594
# Epoch 20/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.4035 - Accuracy: 0.8154 - precision_1: 0.7878 - recall_1: 0.8632 - val_loss: 0.4394 - val_Accuracy: 0.7994 - val_precision_1: 0.7775 - val_recall_1: 0.8393
# Epoch 21/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.4005 - Accuracy: 0.8177 - precision_1: 0.7900 - recall_1: 0.8656 - val_loss: 0.4397 - val_Accuracy: 0.8021 - val_precision_1: 0.7726 - val_recall_1: 0.8564
# Epoch 22/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3975 - Accuracy: 0.8191 - precision_1: 0.7909 - recall_1: 0.8675 - val_loss: 0.4406 - val_Accuracy: 0.8017 - val_precision_1: 0.7614 - val_recall_1: 0.8792
# Epoch 23/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3953 - Accuracy: 0.8208 - precision_1: 0.7924 - recall_1: 0.8693 - val_loss: 0.4378 - val_Accuracy: 0.8034 - val_precision_1: 0.7664 - val_recall_1: 0.8732
# Epoch 24/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3926 - Accuracy: 0.8215 - precision_1: 0.7932 - recall_1: 0.8697 - val_loss: 0.4357 - val_Accuracy: 0.8050 - val_precision_1: 0.7837 - val_recall_1: 0.8428
# Epoch 25/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3902 - Accuracy: 0.8233 - precision_1: 0.7947 - recall_1: 0.8716 - val_loss: 0.4356 - val_Accuracy: 0.8058 - val_precision_1: 0.7732 - val_recall_1: 0.8660
# Epoch 26/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3878 - Accuracy: 0.8242 - precision_1: 0.7956 - recall_1: 0.8725 - val_loss: 0.4344 - val_Accuracy: 0.8054 - val_precision_1: 0.7835 - val_recall_1: 0.8444
# Epoch 27/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3851 - Accuracy: 0.8260 - precision_1: 0.7968 - recall_1: 0.8750 - val_loss: 0.4373 - val_Accuracy: 0.8064 - val_precision_1: 0.7764 - val_recall_1: 0.8609
# Epoch 28/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3835 - Accuracy: 0.8264 - precision_1: 0.7977 - recall_1: 0.8746 - val_loss: 0.4371 - val_Accuracy: 0.8055 - val_precision_1: 0.7683 - val_recall_1: 0.8752
# Epoch 29/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3814 - Accuracy: 0.8276 - precision_1: 0.7989 - recall_1: 0.8755 - val_loss: 0.4396 - val_Accuracy: 0.8064 - val_precision_1: 0.7703 - val_recall_1: 0.8733
# Epoch 30/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3791 - Accuracy: 0.8287 - precision_1: 0.8002 - recall_1: 0.8761 - val_loss: 0.4361 - val_Accuracy: 0.8082 - val_precision_1: 0.7745 - val_recall_1: 0.8698
# Epoch 31/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3770 - Accuracy: 0.8299 - precision_1: 0.8013 - recall_1: 0.8774 - val_loss: 0.4402 - val_Accuracy: 0.8056 - val_precision_1: 0.7904 - val_recall_1: 0.8322
# Epoch 32/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3757 - Accuracy: 0.8304 - precision_1: 0.8016 - recall_1: 0.8782 - val_loss: 0.4323 - val_Accuracy: 0.8085 - val_precision_1: 0.7732 - val_recall_1: 0.8734
# Epoch 33/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3732 - Accuracy: 0.8316 - precision_1: 0.8032 - recall_1: 0.8785 - val_loss: 0.4380 - val_Accuracy: 0.8094 - val_precision_1: 0.7877 - val_recall_1: 0.8475
# Epoch 34/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3716 - Accuracy: 0.8327 - precision_1: 0.8037 - recall_1: 0.8803 - val_loss: 0.4374 - val_Accuracy: 0.8105 - val_precision_1: 0.7778 - val_recall_1: 0.8696
# Epoch 35/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3701 - Accuracy: 0.8332 - precision_1: 0.8044 - recall_1: 0.8805 - val_loss: 0.4352 - val_Accuracy: 0.8111 - val_precision_1: 0.7784 - val_recall_1: 0.8702
# Epoch 36/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3690 - Accuracy: 0.8343 - precision_1: 0.8054 - recall_1: 0.8815 - val_loss: 0.4367 - val_Accuracy: 0.8112 - val_precision_1: 0.7877 - val_recall_1: 0.8524
# Epoch 37/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3677 - Accuracy: 0.8350 - precision_1: 0.8061 - recall_1: 0.8820 - val_loss: 0.4333 - val_Accuracy: 0.8123 - val_precision_1: 0.7762 - val_recall_1: 0.8778
# Epoch 38/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3659 - Accuracy: 0.8355 - precision_1: 0.8068 - recall_1: 0.8822 - val_loss: 0.4368 - val_Accuracy: 0.8126 - val_precision_1: 0.7820 - val_recall_1: 0.8673
# Epoch 39/100
# 6854/6854 [==============================] - 41s 6ms/step - loss: 0.3643 - Accuracy: 0.8366 - precision_1: 0.8076 - recall_1: 0.8836 - val_loss: 0.4386 - val_Accuracy: 0.8122 - val_precision_1: 0.7826 - val_recall_1: 0.8647
# Epoch 40/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3623 - Accuracy: 0.8374 - precision_1: 0.8085 - recall_1: 0.8842 - val_loss: 0.4374 - val_Accuracy: 0.8124 - val_precision_1: 0.7905 - val_recall_1: 0.8503
# Epoch 41/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3611 - Accuracy: 0.8385 - precision_1: 0.8096 - recall_1: 0.8849 - val_loss: 0.4404 - val_Accuracy: 0.8124 - val_precision_1: 0.7810 - val_recall_1: 0.8686
# Epoch 42/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3601 - Accuracy: 0.8387 - precision_1: 0.8099 - recall_1: 0.8852 - val_loss: 0.4434 - val_Accuracy: 0.8118 - val_precision_1: 0.7813 - val_recall_1: 0.8664
# Epoch 43/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3584 - Accuracy: 0.8395 - precision_1: 0.8107 - recall_1: 0.8859 - val_loss: 0.4367 - val_Accuracy: 0.8134 - val_precision_1: 0.7845 - val_recall_1: 0.8646
# Epoch 44/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3574 - Accuracy: 0.8402 - precision_1: 0.8113 - recall_1: 0.8865 - val_loss: 0.4389 - val_Accuracy: 0.8140 - val_precision_1: 0.7864 - val_recall_1: 0.8624
# Epoch 45/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3562 - Accuracy: 0.8409 - precision_1: 0.8123 - recall_1: 0.8867 - val_loss: 0.4406 - val_Accuracy: 0.8140 - val_precision_1: 0.7933 - val_recall_1: 0.8497
# Epoch 46/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3549 - Accuracy: 0.8411 - precision_1: 0.8121 - recall_1: 0.8876 - val_loss: 0.4402 - val_Accuracy: 0.8140 - val_precision_1: 0.7874 - val_recall_1: 0.8605
# Epoch 47/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3536 - Accuracy: 0.8424 - precision_1: 0.8136 - recall_1: 0.8882 - val_loss: 0.4436 - val_Accuracy: 0.8157 - val_precision_1: 0.7740 - val_recall_1: 0.8921
# Epoch 48/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3528 - Accuracy: 0.8426 - precision_1: 0.8135 - recall_1: 0.8887 - val_loss: 0.4448 - val_Accuracy: 0.8139 - val_precision_1: 0.7779 - val_recall_1: 0.8789
# Epoch 49/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3513 - Accuracy: 0.8431 - precision_1: 0.8138 - recall_1: 0.8898 - val_loss: 0.4423 - val_Accuracy: 0.8152 - val_precision_1: 0.7761 - val_recall_1: 0.8861
# Epoch 50/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3510 - Accuracy: 0.8436 - precision_1: 0.8144 - recall_1: 0.8901 - val_loss: 0.4421 - val_Accuracy: 0.8155 - val_precision_1: 0.7872 - val_recall_1: 0.8651
# Epoch 51/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3495 - Accuracy: 0.8439 - precision_1: 0.8149 - recall_1: 0.8898 - val_loss: 0.4397 - val_Accuracy: 0.8149 - val_precision_1: 0.7811 - val_recall_1: 0.8754
# Epoch 52/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3487 - Accuracy: 0.8447 - precision_1: 0.8160 - recall_1: 0.8902 - val_loss: 0.4437 - val_Accuracy: 0.8158 - val_precision_1: 0.7839 - val_recall_1: 0.8721
# Epoch 53/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3472 - Accuracy: 0.8451 - precision_1: 0.8165 - recall_1: 0.8902 - val_loss: 0.4429 - val_Accuracy: 0.8171 - val_precision_1: 0.7920 - val_recall_1: 0.8603
# Epoch 54/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3469 - Accuracy: 0.8452 - precision_1: 0.8162 - recall_1: 0.8908 - val_loss: 0.4424 - val_Accuracy: 0.8172 - val_precision_1: 0.7832 - val_recall_1: 0.8776
# Epoch 55/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3461 - Accuracy: 0.8457 - precision_1: 0.8171 - recall_1: 0.8908 - val_loss: 0.4438 - val_Accuracy: 0.8171 - val_precision_1: 0.7830 - val_recall_1: 0.8777
# Epoch 56/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3447 - Accuracy: 0.8466 - precision_1: 0.8177 - recall_1: 0.8920 - val_loss: 0.4427 - val_Accuracy: 0.8163 - val_precision_1: 0.7855 - val_recall_1: 0.8703
# Epoch 57/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3437 - Accuracy: 0.8471 - precision_1: 0.8182 - recall_1: 0.8924 - val_loss: 0.4420 - val_Accuracy: 0.8174 - val_precision_1: 0.7921 - val_recall_1: 0.8610
# Epoch 58/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3433 - Accuracy: 0.8472 - precision_1: 0.8184 - recall_1: 0.8924 - val_loss: 0.4445 - val_Accuracy: 0.8178 - val_precision_1: 0.7911 - val_recall_1: 0.8638
# Epoch 59/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3417 - Accuracy: 0.8477 - precision_1: 0.8191 - recall_1: 0.8923 - val_loss: 0.4451 - val_Accuracy: 0.8173 - val_precision_1: 0.7820 - val_recall_1: 0.8802
# Epoch 60/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3414 - Accuracy: 0.8482 - precision_1: 0.8192 - recall_1: 0.8936 - val_loss: 0.4484 - val_Accuracy: 0.8168 - val_precision_1: 0.7951 - val_recall_1: 0.8537
# Epoch 61/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3399 - Accuracy: 0.8483 - precision_1: 0.8196 - recall_1: 0.8931 - val_loss: 0.4443 - val_Accuracy: 0.8186 - val_precision_1: 0.7874 - val_recall_1: 0.8731
# Epoch 62/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3389 - Accuracy: 0.8494 - precision_1: 0.8206 - recall_1: 0.8943 - val_loss: 0.4475 - val_Accuracy: 0.8171 - val_precision_1: 0.7873 - val_recall_1: 0.8691
# Epoch 63/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3387 - Accuracy: 0.8496 - precision_1: 0.8209 - recall_1: 0.8943 - val_loss: 0.4545 - val_Accuracy: 0.8169 - val_precision_1: 0.7937 - val_recall_1: 0.8565
# Epoch 64/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3374 - Accuracy: 0.8502 - precision_1: 0.8218 - recall_1: 0.8944 - val_loss: 0.4512 - val_Accuracy: 0.8184 - val_precision_1: 0.7894 - val_recall_1: 0.8689
# Epoch 65/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3368 - Accuracy: 0.8498 - precision_1: 0.8213 - recall_1: 0.8941 - val_loss: 0.4502 - val_Accuracy: 0.8186 - val_precision_1: 0.7943 - val_recall_1: 0.8602
# Epoch 66/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3361 - Accuracy: 0.8503 - precision_1: 0.8217 - recall_1: 0.8947 - val_loss: 0.4467 - val_Accuracy: 0.8190 - val_precision_1: 0.7895 - val_recall_1: 0.8701
# Epoch 67/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3351 - Accuracy: 0.8509 - precision_1: 0.8225 - recall_1: 0.8949 - val_loss: 0.4460 - val_Accuracy: 0.8194 - val_precision_1: 0.7801 - val_recall_1: 0.8897
# Epoch 68/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3345 - Accuracy: 0.8514 - precision_1: 0.8226 - recall_1: 0.8960 - val_loss: 0.4535 - val_Accuracy: 0.8182 - val_precision_1: 0.7917 - val_recall_1: 0.8638
# Epoch 69/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3341 - Accuracy: 0.8516 - precision_1: 0.8230 - recall_1: 0.8958 - val_loss: 0.4550 - val_Accuracy: 0.8175 - val_precision_1: 0.7976 - val_recall_1: 0.8514
# Epoch 70/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3334 - Accuracy: 0.8519 - precision_1: 0.8233 - recall_1: 0.8960 - val_loss: 0.4589 - val_Accuracy: 0.8166 - val_precision_1: 0.8046 - val_recall_1: 0.8365
# Epoch 71/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3328 - Accuracy: 0.8521 - precision_1: 0.8234 - recall_1: 0.8965 - val_loss: 0.4518 - val_Accuracy: 0.8190 - val_precision_1: 0.7834 - val_recall_1: 0.8821
# Epoch 72/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3319 - Accuracy: 0.8525 - precision_1: 0.8240 - recall_1: 0.8965 - val_loss: 0.4503 - val_Accuracy: 0.8186 - val_precision_1: 0.7948 - val_recall_1: 0.8592
# Epoch 73/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3312 - Accuracy: 0.8529 - precision_1: 0.8242 - recall_1: 0.8972 - val_loss: 0.4551 - val_Accuracy: 0.8190 - val_precision_1: 0.7800 - val_recall_1: 0.8889
# Epoch 74/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3307 - Accuracy: 0.8536 - precision_1: 0.8249 - recall_1: 0.8976 - val_loss: 0.4528 - val_Accuracy: 0.8200 - val_precision_1: 0.7920 - val_recall_1: 0.8682
# Epoch 75/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3300 - Accuracy: 0.8536 - precision_1: 0.8252 - recall_1: 0.8973 - val_loss: 0.4552 - val_Accuracy: 0.8191 - val_precision_1: 0.7898 - val_recall_1: 0.8701
# Epoch 76/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3287 - Accuracy: 0.8546 - precision_1: 0.8262 - recall_1: 0.8980 - val_loss: 0.4561 - val_Accuracy: 0.8193 - val_precision_1: 0.7846 - val_recall_1: 0.8804
# Epoch 77/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3281 - Accuracy: 0.8540 - precision_1: 0.8257 - recall_1: 0.8974 - val_loss: 0.4592 - val_Accuracy: 0.8197 - val_precision_1: 0.7869 - val_recall_1: 0.8772
# Epoch 78/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3276 - Accuracy: 0.8549 - precision_1: 0.8263 - recall_1: 0.8987 - val_loss: 0.4568 - val_Accuracy: 0.8213 - val_precision_1: 0.7903 - val_recall_1: 0.8749
# Epoch 79/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3272 - Accuracy: 0.8548 - precision_1: 0.8262 - recall_1: 0.8986 - val_loss: 0.4578 - val_Accuracy: 0.8197 - val_precision_1: 0.7879 - val_recall_1: 0.8754
# Epoch 80/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3260 - Accuracy: 0.8561 - precision_1: 0.8276 - recall_1: 0.8995 - val_loss: 0.4565 - val_Accuracy: 0.8213 - val_precision_1: 0.7990 - val_recall_1: 0.8588
# Epoch 81/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3264 - Accuracy: 0.8555 - precision_1: 0.8271 - recall_1: 0.8989 - val_loss: 0.4576 - val_Accuracy: 0.8201 - val_precision_1: 0.7864 - val_recall_1: 0.8792
# Epoch 82/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3256 - Accuracy: 0.8560 - precision_1: 0.8278 - recall_1: 0.8989 - val_loss: 0.4601 - val_Accuracy: 0.8197 - val_precision_1: 0.7784 - val_recall_1: 0.8941
# Epoch 83/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3247 - Accuracy: 0.8563 - precision_1: 0.8278 - recall_1: 0.8997 - val_loss: 0.4580 - val_Accuracy: 0.8221 - val_precision_1: 0.7969 - val_recall_1: 0.8648
# Epoch 84/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3240 - Accuracy: 0.8570 - precision_1: 0.8287 - recall_1: 0.9000 - val_loss: 0.4717 - val_Accuracy: 0.8181 - val_precision_1: 0.7752 - val_recall_1: 0.8963
# Epoch 85/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3239 - Accuracy: 0.8570 - precision_1: 0.8287 - recall_1: 0.9000 - val_loss: 0.4639 - val_Accuracy: 0.8227 - val_precision_1: 0.7935 - val_recall_1: 0.8727
# Epoch 86/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3231 - Accuracy: 0.8571 - precision_1: 0.8288 - recall_1: 0.9000 - val_loss: 0.4624 - val_Accuracy: 0.8203 - val_precision_1: 0.8045 - val_recall_1: 0.8465
# Epoch 87/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3228 - Accuracy: 0.8572 - precision_1: 0.8288 - recall_1: 0.9005 - val_loss: 0.4608 - val_Accuracy: 0.8192 - val_precision_1: 0.8010 - val_recall_1: 0.8496
# Epoch 88/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3217 - Accuracy: 0.8580 - precision_1: 0.8296 - recall_1: 0.9009 - val_loss: 0.4626 - val_Accuracy: 0.8211 - val_precision_1: 0.7924 - val_recall_1: 0.8706
# Epoch 89/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3215 - Accuracy: 0.8577 - precision_1: 0.8294 - recall_1: 0.9006 - val_loss: 0.4620 - val_Accuracy: 0.8221 - val_precision_1: 0.7879 - val_recall_1: 0.8818
# Epoch 90/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3211 - Accuracy: 0.8573 - precision_1: 0.8290 - recall_1: 0.9003 - val_loss: 0.4639 - val_Accuracy: 0.8224 - val_precision_1: 0.7907 - val_recall_1: 0.8773
# Epoch 91/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3202 - Accuracy: 0.8579 - precision_1: 0.8299 - recall_1: 0.9003 - val_loss: 0.4636 - val_Accuracy: 0.8212 - val_precision_1: 0.7930 - val_recall_1: 0.8697
# Epoch 92/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3203 - Accuracy: 0.8585 - precision_1: 0.8304 - recall_1: 0.9010 - val_loss: 0.4674 - val_Accuracy: 0.8210 - val_precision_1: 0.7993 - val_recall_1: 0.8573
# Epoch 93/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3194 - Accuracy: 0.8595 - precision_1: 0.8312 - recall_1: 0.9021 - val_loss: 0.4711 - val_Accuracy: 0.8219 - val_precision_1: 0.7940 - val_recall_1: 0.8697
# Epoch 94/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3188 - Accuracy: 0.8590 - precision_1: 0.8312 - recall_1: 0.9010 - val_loss: 0.4622 - val_Accuracy: 0.8217 - val_precision_1: 0.7956 - val_recall_1: 0.8660
# Epoch 95/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3190 - Accuracy: 0.8593 - precision_1: 0.8310 - recall_1: 0.9020 - val_loss: 0.4683 - val_Accuracy: 0.8213 - val_precision_1: 0.7905 - val_recall_1: 0.8746
# Epoch 96/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3180 - Accuracy: 0.8599 - precision_1: 0.8318 - recall_1: 0.9023 - val_loss: 0.4619 - val_Accuracy: 0.8221 - val_precision_1: 0.7895 - val_recall_1: 0.8787
# Epoch 97/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3174 - Accuracy: 0.8597 - precision_1: 0.8319 - recall_1: 0.9017 - val_loss: 0.4726 - val_Accuracy: 0.8209 - val_precision_1: 0.7790 - val_recall_1: 0.8963
# Epoch 98/100
# 6854/6854 [==============================] - 42s 6ms/step - loss: 0.3164 - Accuracy: 0.8603 - precision_1: 0.8322 - recall_1: 0.9025 - val_loss: 0.4694 - val_Accuracy: 0.8219 - val_precision_1: 0.7865 - val_recall_1: 0.8840
# Epoch 99/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3165 - Accuracy: 0.8602 - precision_1: 0.8319 - recall_1: 0.9027 - val_loss: 0.4674 - val_Accuracy: 0.8218 - val_precision_1: 0.7899 - val_recall_1: 0.8772
# Epoch 100/100
# 6854/6854 [==============================] - 43s 6ms/step - loss: 0.3160 - Accuracy: 0.8606 - precision_1: 0.8326 - recall_1: 0.9025 - val_loss: 0.4715 - val_Accuracy: 0.8235 - val_precision_1: 0.7976 - val_recall_1: 0.8675

# %%
import pickle

pickle.dump(scaler, open('scaler.pkl','wb'))
model.save('heartModel')
model.save('weights.h5')
# Out:
# INFO:tensorflow:Assets written to: heartModel/assets

# %%
# !tar -zhcf heartModel.tar.gz heartModel
# !tar -zhcf heartModelWeights.tar.gz weights.h5
# !tar -zhcf scaler.tar.gz scaler.pkl

# %%
# !pip install ibm_watson_machine_learning --upgrade
from ibm_watson_machine_learning import APIClient

wml_credentials = {
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey": "NYNAwOBjNJ-NYGxFBqt9g5wy00B3LFeO05QM7knU1Gmz"
}

client = APIClient(wml_credentials)
# Out:
# Requirement already satisfied: ibm_watson_machine_learning in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (1.0.204)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (2021.10.8)
# Requirement already satisfied: ibm-cos-sdk==2.11.* in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (2.11.0)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (0.3.3)
# Requirement already satisfied: pandas<1.4.0,>=0.24.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (1.3.4)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (4.8.2)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (1.26.7)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (0.8.9)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (21.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm_watson_machine_learning) (2.26.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cos-sdk==2.11.*->ibm_watson_machine_learning) (0.10.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.11.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cos-sdk==2.11.*->ibm_watson_machine_learning) (2.11.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.11.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cos-sdk==2.11.*->ibm_watson_machine_learning) (2.11.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cos-sdk-core==2.11.0->ibm-cos-sdk==2.11.*->ibm_watson_machine_learning) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pandas<1.4.0,>=0.24.2->ibm_watson_machine_learning) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pandas<1.4.0,>=0.24.2->ibm_watson_machine_learning) (1.20.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->ibm-cos-sdk-core==2.11.0->ibm-cos-sdk==2.11.*->ibm_watson_machine_learning) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->ibm_watson_machine_learning) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->ibm_watson_machine_learning) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from importlib-metadata->ibm_watson_machine_learning) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from packaging->ibm_watson_machine_learning) (3.0.4)

# %%
def guide_from_space_name(client, space_name):
    space = client.spaces.get_details()
    return (next(item for item in space['resources'] if item['entity']['name']== space_name)['metadata']['id'])

# %%
space_uid = guide_from_space_name(client, 'tensorflowModel')
print('Space UID:', space_uid)
# Out:
# Space UID: f6d73f2e-a744-4358-8162-129f9eebc405

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list()
# Out:
# -------------------------------  ------------------------------------  ----
# NAME                             ASSET_ID                              TYPE
# default_py3.6                    0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# pytorch-onnx_1.3-py3.7-edt       069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6          09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12       09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# pytorch-onnx_rt22.1-py3.9        0b848dd4-e681-5599-be41-b5f6fccc6471  base
# ai-function_0.1-py3.6            0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                       0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod     1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6                10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# tensorflow_1.15-py3.6-ddl        111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# runtime-22.1-py3.9               12b83a17-24d8-5082-900f-0ab31fbfd3cb  base
# scikit-learn_0.22-py3.6          154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base
# default_r3.6                     1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base
# pytorch-onnx_1.3-py3.6           1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base
# pytorch-onnx_rt22.1-py3.9-edt    1d362186-7ad5-5b59-8b6c-9d0880bde37f  base
# tensorflow_2.1-py3.6             1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base
# tensorflow_2.4-py3.8-horovod     217c16f6-178f-56bf-824a-b19f20564c49  base
# runtime-22.1-py3.9-cuda          26215f05-08c3-5a41-a1b0-da66306ce658  base
# do_py3.8                         295addb5-9ef9-547e-9bf4-92ae3563e720  base
# autoai-ts_3.8-py3.8              2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base
# tensorflow_1.15-py3.6            2b73a275-7cbf-420b-a912-eae7f436e0bc  base
# pytorch_1.2-py3.6                2c8ef57d-2687-4b7d-acce-01f94976dac1  base
# spark-mllib_2.3                  2e51f700-bca0-4b0d-88dc-5c6791338875  base
# pytorch-onnx_1.1-py3.6-edt       32983cea-3f32-4400-8965-dde874a8d67e  base
# spark-mllib_3.0-py37             36507ebe-8770-55ba-ab2a-eafe787600e9  base
# spark-mllib_2.4                  390d21f8-e58b-4fac-9c55-d7ceda621326  base
# xgboost_0.82-py3.6               39e31acd-5f30-41dc-ae44-60233c80306e  base
# pytorch-onnx_1.2-py3.6-edt       40589d0e-7019-4e28-8daa-fb03b6f4fe12  base
# default_r36py38                  41c247d3-45f8-5a71-b065-8580229facf0  base
# autoai-ts_rt22.1-py3.9           4269d26e-07ba-5d40-8f66-2d495b0c71f7  base
# autoai-obm_3.0                   42b92e18-d9ab-567f-988a-4240ba1ed5f7  base
# pmml-3.0_4.3                     493bcb95-16f1-5bc5-bee8-81b8af80e9c7  base
# spark-mllib_2.4-r_3.6            49403dff-92e9-4c87-a3d7-a42d0021c095  base
# xgboost_0.90-py3.6               4ff8d6c2-1343-4c18-85e1-689c965304d3  base
# pytorch-onnx_1.1-py3.6           50f95b2a-bc16-43bb-bc94-b0bed208c60b  base
# autoai-ts_3.9-py3.8              52c57136-80fa-572e-8728-a5e7cbb42cde  base
# spark-mllib_2.4-scala_2.11       55a70f99-7320-4be5-9fb9-9edb5a443af5  base
# spark-mllib_3.0                  5c1b0ca2-4977-5c2e-9439-ffd44ea8ffe9  base
# autoai-obm_2.0                   5c2e37fa-80b8-5e77-840f-d912469614ee  base
# spss-modeler_18.1                5c3cad7e-507f-4b2a-a9a3-ab53a21dee8b  base
# cuda-py3.8                       5d3232bf-c86b-5df4-a2cd-7bb870a1cd4e  base
# autoai-kb_3.1-py3.7              632d4b22-10aa-5180-88f0-f52dfb6444d7  base
# pytorch-onnx_1.7-py3.8           634d3cdc-b562-5bf9-a2d4-ea90a478456b  base
# spark-mllib_2.3-r_3.6            6586b9e3-ccd6-4f92-900f-0f8cb2bd6f0c  base
# tensorflow_2.4-py3.7             65e171d7-72d1-55d9-8ebb-f813d620c9bb  base
# spss-modeler_18.2                687eddc9-028a-4117-b9dd-e57b36f1efa5  base
# pytorch-onnx_1.2-py3.6           692a6a4d-2c4d-45ff-a1ed-b167ee55469a  base
# spark-mllib_2.3-scala_2.11       7963efe5-bbec-417e-92cf-0574e21b4e8d  base
# spark-mllib_2.4-py37             7abc992b-b685-532b-a122-a396a3cdbaab  base
# caffe_1.0-py3.6                  7bb3dbe2-da6e-4145-918d-b6d84aa93b6b  base
# pytorch-onnx_1.7-py3.7           812c6631-42b7-5613-982b-02098e6c909c  base
# cuda-py3.6                       82c79ece-4d12-40e6-8787-a7b9e0f62770  base
# tensorflow_1.15-py3.6-horovod    8964680e-d5e4-5bb8-919b-8342c6c0dfd8  base
# hybrid_0.1                       8c1a58c6-62b5-4dc4-987a-df751c2756b6  base
# pytorch-onnx_1.3-py3.7           8d5d8a87-a912-54cf-81ec-3914adaa988d  base
# caffe-ibm_1.0-py3.6              8d863266-7927-4d1e-97d7-56a7f4c0a19b  base
# spss-modeler_17.1                902d0051-84bd-4af6-ab6b-8f6aa6fdeabb  base
# do_12.10                         9100fd72-8159-4eb9-8a0b-a87e12eefa36  base
# do_py3.7                         9447fa8b-2051-4d24-9eef-5acb0e3c59f8  base
# spark-mllib_3.0-r_3.6            94bb6052-c837-589d-83f1-f4142f219e32  base
# cuda-py3.7-opence                94e9652b-7f2d-59d5-ba5a-23a414ea488f  base
# nlp-py3.8                        96e60351-99d4-5a1c-9cc0-473ac1b5a864  base
# cuda-py3.7                       9a44990c-1aa1-4c7d-baf8-c4099011741c  base
# hybrid_0.2                       9b3f9040-9cee-4ead-8d7a-780600f542f7  base
# spark-mllib_3.0-py38             9f7a8fc1-4d3c-5e65-ab90-41fa8de2d418  base
# autoai-kb_3.3-py3.7              a545cca3-02df-5c61-9e88-998b09dc79af  base
# spark-mllib_3.0-py39             a6082a27-5acc-5163-b02c-6b96916eb5e0  base
# runtime-22.1-py3.9-do            a7e7dbf1-1d03-5544-994d-e5ec845ce99a  base
# default_py3.8                    ab9e1b80-f2ce-592c-a7d2-4f2344f77194  base
# tensorflow_rt22.1-py3.9          acd9c798-6974-5d2f-a657-ce06e986df4d  base
# autoai-obm_2.0 with Spark 3.0    af10f35f-69fa-5d66-9bf5-acb58434263a  base
# default_py3.7_opence             c2057dd4-f42c-5f77-a02f-72bdbd3282c9  base
# tensorflow_2.1-py3.7             c4032338-2a40-500a-beef-b01ab2667e27  base
# do_py3.7_opence                  cc8f8976-b74a-551a-bb66-6377f8d865b4  base
# autoai-kb_3.0-py3.6              d139f196-e04b-5d8b-9140-9a10ca1fa91a  base
# spark-mllib_3.0-py36             d82546d5-dd78-5fbb-9131-2ec309bc56ed  base
# autoai-kb_3.4-py3.8              da9b39c3-758c-5a4f-9cfd-457dd4d8c395  base
# autoai-kb_rt22.1-py3.9           db6afe93-665f-5910-b117-d879897404d9  base
# tensorflow_rt22.1-py3.9-horovod  dda170cc-ca67-5da7-9b7a-cf84c6987fae  base
# autoai-ts_1.0-py3.7              deef04f0-0c42-5147-9711-89f9904299db  base
# tensorflow_2.1-py3.7-horovod     e384fce5-fdd1-53f8-bc71-11326c9c635f  base
# default_py3.7                    e4429883-c883-42b6-87a8-f419d64088cd  base
# do_20.1                          f686cdd9-7904-5f9d-a732-01b0d6b10dc5  base
# scikit-learn_0.19-py3.6          f963fa9d-4bb7-5652-9c5d-8d9289ef6ad9  base
# tensorflow_2.4-py3.8             fe185c44-9a99-5425-986b-59bd1d2eda46  base
# -------------------------------  ------------------------------------  ----

# %%
software_spec_uid = client.software_specifications.get_uid_by_name("tensorflow_rt22.1-py3.9-horovod")
software_spec_uid
# Out:
# 'dda170cc-ca67-5da7-9b7a-cf84c6987fae'

# %%
software_spec_uid_2 = client.software_specifications.get_uid_by_name('runtime-22.1-py3.9')
software_spec_uid_2
# Out:
# '12b83a17-24d8-5082-900f-0ab31fbfd3cb'

# %%
model_details = client.repository.store_model(model='heartModel.tar.gz', meta_props={
    client.repository.ModelMetaNames.NAME: "Heart_model",
    client.repository.ModelMetaNames.TYPE: "tensorflow_2.4",
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid
})

model_id = client.repository.get_model_id(model_details)
model_id
# Out:
# '62898150-f84e-4a50-a1ee-5f9d26150822'

# %%
model_weight_details = client.repository.store_model(model='heartModelWeights.tar.gz', meta_props={
    client.repository.ModelMetaNames.NAME: "Heart_model_weight",
    client.repository.ModelMetaNames.TYPE: "tensorflow_2.4",
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid
})

model_weights_id = client.repository.get_model_id(model_weight_details)
model_weights_id
# Out:
# 'edcf61e3-0db9-41ae-a93e-480b7982135f'

# %%
scikit_model_details = client.repository.store_model(model='scaler.tar.gz', meta_props={
    client.repository.ModelMetaNames.NAME: "scaler",
    client.repository.ModelMetaNames.TYPE: "scikit-learn_1.0",
    client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: software_spec_uid_2
})

model_id_2 = client.repository.get_model_id(scikit_model_details)
model_id_2
# Out:
# 'c6974477-36bc-4dfd-93bc-188a3dacfd4b'

# %%
client.repository.download(model_id, "my_model.tar.gz")
# Out:
# Successfully saved model content to file: 'my_model.tar.gz'
# '/home/wsuser/work/my_model.tar.gz'

# %%
sample_model = tf.keras.models.load_model('heartModel')

# %%
from pickle import load

# %%
# !dir
# Out:
# heartModel	   heartModelWeights.tar.gz  scaler.pkl
# heartModel.tar.gz  my_model.tar.gz	     weights.h5

# %%
sample = load(open('scaler.pkl','rb'), encoding='bytes')

# %%
import pickle
pickle.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/wsuser/ipykernel_154/517198032.py in <module>
#       1 import pickle
# ----> 2 pickle.__version__
#
# AttributeError: module 'pickle' has no attribute '__version__'

# %%
scaler.feature_names_in_
# Out:
# array(['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime'], dtype=object)
